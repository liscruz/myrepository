# %%
import pandas as pd
import json
import pymongo
import calendar
data = pd.read_csv('listings.csv.gz', compression='gzip',
                   error_bad_lines=False, low_memory=False)
print(len(data))
# Out:
# 50599

# %%
for c in data.columns:
    print(c)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# name
# summary
# space
# description
# experiences_offered
# neighborhood_overview
# notes
# transit
# access
# interaction
# house_rules
# thumbnail_url
# medium_url
# picture_url
# xl_picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# street
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# zipcode
# market
# smart_location
# country_code
# country
# latitude
# longitude
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# bed_type
# amenities
# square_feet
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# guests_included
# ...

# %%
data.groupby(['host_is_superhost']).count()
# Out:
#                       id  listing_url  scrape_id  last_scraped   name  \
# host_is_superhost
# f                  40225        40225      40225         40225  40209
# t                   9811         9811       9811          9811   9811
#
#                    summary  space  description  experiences_offered  \
# host_is_superhost
# f                    38343  27543        39282                40225
# t                     9496   8488         9734                 9811
#
#                    neighborhood_overview  ...  instant_bookable  \
# host_is_superhost                         ...
# f                                  24837  ...             40225
# t                                   7890  ...              9811
#
#                    is_business_travel_ready  cancellation_policy  \
# host_is_superhost
# f                                     40225                40225
# t                                      9811                 9811
#
# ...

# %%
drop_columns = ['listing_url', 'scrape_id', 'last_scraped', 'space', 'description', 'experiences_offered', 
                'neighborhood_overview', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 
                'picture_url', 'xl_picture_url', 'host_url', 'host_location', 
                'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms',
               'calculated_host_listings_count_shared_rooms', 'host_picture_url', 'zipcode','market',
               'smart_location', 'country_code', 'country', 'is_location_exact', 'square_feet', 'calendar_updated',
               'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 
                'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability', 'availability_30', 
                'availability_60', 'availability_90', 'number_of_reviews_ltm', 'first_review', 'last_review', 
                'requires_license', 'license', 'jurisdiction_names', 'is_business_travel_ready', 
                'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms',
                'calculated_host_listings_count_shared_rooms', 'notes']


df = data.drop(drop_columns, axis=1)

# %%
df
# Out:
#              id                                               name  \
# 0          2595                              Skylit Midtown Castle
# 1          3831                    Cozy Entire Floor of Brownstone
# 2          5099          Large Cozy 1 BR Apartment In Midtown East
# 3          5121                                    BlissArtsSpace!
# 4          5178                   Large Furnished Room Near B'way
# 5          5203                 Cozy Clean Guest Room - Family Apt
# 6          5238                 Cute & Cozy Lower East Side 1 bdrm
# 7          5441                    Central Manhattan/near Broadway
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental
# 9          6090                      West Village Nest - Superhost
# 10         6848                   Only 2 stops to Manhattan studio
# 11         7097                  Perfect for Your Parents + Garden
# 12         7322   Chelsea Perfect  by Doti, an AIRBNB  Super Host!
# ...

# %% [markdown]
# cols = ['city','state']
# df= data[cols]
# df
# data['zipcode'].unique()

# %%
df= data['zipcode'].unique()
df
# Out:
# array(['10018', '11238', '10016', '11216', '10019', '10025', '10002',
#        '10036', '11215', '10014', '11211', '11205', '10011', '10029',
#        '11217', '11218', '10034', '10003', '10031', '10027', '11222',
#        '11237', '11226', '10009', '10024', '11225', '11101', '11221',
#        '11206', '10010', '11249', '10001', '10162', '11231', '10035',
#        '10032', '11377', '11201', '11233', '10023', '10128', '11234',
#        '11367', '10028', '10069', '11104', '10065', '10301', '10013',
#        '10452', '10039', '11385', '10454', '10021', '10075', '11434',
#        '11379', '10026', '11105', '10044', '10022', '11103', '10473',
#        '10475', '10468', nan, '11102', '10038', '11213', '10033', '11427',
#        '11693', '10012', '11375', '10470', '10030', '11207', '10453',
#        '11223', '10469', '11208', '11235', '11209', '11204', '10305',
#        '11232', '11418', '10017', '11373', '11372', '11412', '10004',
# ...

# %%
#fin#fill NaN data with 0 in the dataframe and display the data
data.fillna('0',inplace=True)
data
# Out:
#              id                            listing_url       scrape_id  \
# 0          2595      https://www.airbnb.com/rooms/2595  20191204162729
# 1          3831      https://www.airbnb.com/rooms/3831  20191204162729
# 2          5099      https://www.airbnb.com/rooms/5099  20191204162729
# 3          5121      https://www.airbnb.com/rooms/5121  20191204162729
# 4          5178      https://www.airbnb.com/rooms/5178  20191204162729
# 5          5203      https://www.airbnb.com/rooms/5203  20191204162729
# 6          5238      https://www.airbnb.com/rooms/5238  20191204162729
# 7          5441      https://www.airbnb.com/rooms/5441  20191204162729
# 8          5803      https://www.airbnb.com/rooms/5803  20191204162729
# 9          6090      https://www.airbnb.com/rooms/6090  20191204162729
# 10         6848      https://www.airbnb.com/rooms/6848  20191204162729
# 11         7097      https://www.airbnb.com/rooms/7097  20191204162729
# ...

# %%
boroughs_data = {"Manhattan":
[10026, 10027, 10030, 10037, 10039,
10001, 10011, 10018, 10019, 10020, 10036,
10029, 10035,
10010, 10016, 10017, 10022,
10012, 10013, 10014,
10004, 10005, 10006, 10007, 10038, 10280,
10002, 10003, 10009,
10021, 10028, 10044, 10065, 10075, 10128,
10023, 10024, 10025,
10031, 10032, 10033, 10034, 10040],

"Brooklyn": [11212, 11213, 11216, 11233, 11238,
11209, 11214, 11228,
11204, 11218, 11219, 11230,
11234, 11236, 11239,
11223, 11224, 11229, 11235,
11201, 11205, 11215, 11217, 11231,
11203, 11210, 11225, 11226,
11207, 11208,
11211, 11222,
11220, 11232,
11206, 11221, 11237],

"Queens":[11361, 11362, 11363, 11364,
11354, 11355, 11356, 11357, 11358, 11359, 11360,
11365, 11366, 11367,
11412, 11423, 11432, 11433, 11434, 11435, 11436,
11101, 11102, 11103, 11104, 11105, 11106,
11374, 11375, 11379, 11385,
11691, 11692, 11693, 11694, 11695, 11697,
11004, 11005, 11411, 11413, 11422, 11426, 11427, 11428, 11429,
11414, 11415, 11416, 11417, 11418, 11419, 11420, 11421,
11368, 11369, 11370, 11372, 11373, 11377, 11378],
 
"The Bronx": 
[10453, 10457, 10460,
10458, 10467, 10468,
10451, 10452, 10456,
10454, 10455, 10459, 10474,
10463, 10471, 10466, 10469, 10470, 10475,
10461, 10462,10464, 10465, 10472, 10473],

"Staten Island":[10302, 10303, 10310,
10306, 10307, 10308, 10309, 10312,
10301, 10304, 10305,
10314],
}

items_pd = pd.DataFrame(boroughs_data, columns=[
                        "Manhattan", "Brooklyn", "Queens", "The Bronx", "Staten Island"])
items_pd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-c5e50686cbb6> in <module>
#      49
#      50 items_pd = pd.DataFrame(boroughs_data, columns=[
# ---> 51                         "Manhattan", "Brooklyn", "Queens", "The Bronx", "Staten Island"])
#      52 items_pd
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     182             # GH10856
# ...

# %%
# Count how many sightings have occured within each state
new_df = data["zipcode"].value_counts()
.head()print(boroughs)
# Out:
# 11211           2206
# 11221           1962
# 11206           1538
# 11216           1446
# 10019           1296
# 10002           1282
# 10009           1147
# 11222           1127
# 11238           1107
# 10003           1070
# 11237           1063
# 10025           1048
# 10036           1011
# 10016            990
# 11233            986
# 11215            861
# 10011            836
# 11205            830
# 10031            824
# 10027            819
# 11249            772
# 11226            729
# 10014            729
# 10012            712
# 10029            711
# 11217            600
# 11207            600
# 11225            599
# 11213            589
# 10001            560
#                 ...
# 10309              4
# NY 10075           3
# 10129              3
# 11239              3
# NY 11201           3
# NY 10004           3
# 11363              3
# 10705              3
# 10281              2
# NY 10022           2
# NY 10038           2
# NY 10128           2
# ...

# %%
# Using GroupBy in order to separate the data into fields according to "zipcode" values
grouped_df = data.groupby(['zipcode'])

# The object returned is a "GroupBy" object and cannot be viewed normally...
print(grouped_df)

# In order to be visualized, a data function must be used...
grouped_df.count().head(10)
# Out:
# ...
#               id  listing_url  scrape_id  last_scraped  name  summary  space  \
# zipcode
#                1            1          1             1     1        1      1
#  11374         1            1          1             1     1        1      1
# 0            465          465        465           465   465      465    465
# 07093          1            1          1             1     1        1      1
# 10001        560          560        560           560   560      560    560
# 10002       1282         1282       1282          1282  1282     1282   1282
# 10002-2289     1            1          1             1     1        1      1
# 10003       1070         1070       1070          1070  1070     1070   1070
# 10004         63           63         63            63    63       63     63
# 10005        289          289        289           289   289      289    289
#
#             description  experiences_offered  neighborhood_overview  ...  \
# ...
